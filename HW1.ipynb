# %% [markdown]
# <a href="https://colab.research.google.com/github/KuoZiyun/Econometrics/blob/main/412351093(HW1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd


url = "https://www.taifex.com.tw/cht/3/pcRatio"
payload = {
    "queryStartDate":"2025/09/09",
    "queryEndDate":"2025/10/08"
}

payload["queryDate"] = "2025/10/08"
res = requests.post(url,data = payload)
soup = bs(res.text,"lxml")
tb = soup.select("table")[0]
df = pd.read_html(str(tb))[0]
df
# Out:
# /tmp/ipython-input-597523061.py:16: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(tb))[0]
#            日期   賣權成交量   買權成交量  買賣權成交量比率%  賣權未平倉量  買權未平倉量  買賣權未平倉量比率%
# 0   2025/10/8  595623  643852      92.51  106288   75973      139.90
# 1   2025/10/7  377199  318337     118.49  181885  113151      160.75
# 2   2025/10/3  569130  561701     101.32  118210   80963      146.00
# 3   2025/10/2  360190  336503     107.04  160620  110992      144.71
# 4   2025/10/1  694897  644086     107.89  106748   76270      139.96
# 5   2025/9/30  337960  289505     116.74  155073  116013      133.67
# 6   2025/9/26  707749  746752      94.78   96295   92828      103.73
# 7   2025/9/25  269088  274042      98.19  136554  111913      122.02
# 8   2025/9/24  738912  733431     100.75   98078   71529      137.12
# ...
